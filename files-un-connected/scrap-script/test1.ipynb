# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd



url = 'https://www.rayashop.com/ar/mobiles-and-tablets/?p=2'
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"
          }
s = requests.Session()
s.headers.update(headers)
r = s.get(url)
soup = bs(r.content , "html.parser")
print(soup)
# Out:
#  <!DOCTYPE html>
# <html lang="ar"><head> <meta charset="utf-8"/>
# <meta content="افضل اسعار الموبايلات والتابلت - اشترى من رايه شوب | مصر | Page 2 | Page 2" name="title"/>
# <meta content="اشتري بافضل اسعار الموبايلات والتابلت وامكانية التقسيط المباشر مع رايه شوب - افضل سعر موبايل كاش في مصر - شحن سريع - توصيل الي باب المنزل - رايه شوب | مصر | Page 2" name="description"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>افضل اسعار الموبايلات والتابلت - اشترى من رايه شوب | مصر | Page 2 | Page 2</title>
# <link href="https://www.rayashop.com/static/version1639515039/_cache/merged/cfe45c5b9c275dbb1239777553494c82.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.rayashop.com/static/version1639515039/frontend/Gazri/ready/ar_EG/css/styles-l.min.css" media="screen and (min-width: 768px)" rel="stylesheet" type="text/css"/>
# ...

# %%
product_list_raya = soup.find_all('li',{'class':'item product product-item'})
print(len(product_list_raya))
for product in product_list_raya:
    print(product)
# Out:
# 20
# <li class="item product product-item"><div class="product-item-info" data-container="product-grid" id="product-item-info_78006"> <a class="product photo product-item-photo" href="https://www.rayashop.com/ar/huawei-nova-9-dual-sim-128gb-8gb-ram-4g-lte-blue-book-now-with-free-gift" tabindex="-1"> <div class="list_product_id product_78006" style="display:none;"></div><span class="product-image-container product-image-container-78006"><span class="product-image-wrapper"><img alt="هواوي نوفا 9 ثنائي الشريحة، 128 جيجابايت، 8 جيجا رام، شبكة الجيل الرابع إل تي إي، أزرق (احجز الآن مع هدية مجانية)" class="product-image-photo" height="300" loading="lazy" src="https://www.rayashop.com/media/catalog/product/n/o/nova_9_blue.jpg?optimize=high&amp;bg-color=255,255,255&amp;fit=bounds&amp;height=300&amp;width=240&amp;canvas=240:300" width="240"/></span></span> <style>.product-image-container-78006 {
#     width: 240px;
# }
# .product-image-container-78006 span.product-image-wrapper {
# ...
