# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd



url = 'https://www.samsung.com/eg/support/partsprices/'
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"
          }
s = requests.Session()
s.headers.update(headers)
r = s.get(url)
soup = bs(r.content , "html.parser")
tables_num = len(soup.findAll('div', class_='ex-g-table-cell-text'))
tables = soup.findAll('div', class_='ex-g-table-cell-text')

table= soup.find('div', class_='ex-g-table-cell-text')
table2 = table.fetchNextSiblings('div', class_='ex-g-table-cell-text')
table_lists = []
table_lists.extend(table)
table_lists.extend(table2)

table.nextGenerato
#print(tables[0:5])
print(len(table_lists))
print(len(table2))
print(len(table))
# Out:
# 7
# 5
# 2

# %%
mobs = {}
num = 0
print(type(table_lists))
print(type(tables))
for trr in table_lists: #
    print('>>>>>>>>> Start')

    print(trr.text)
    #print(type(trr))
    print('>>>>>>>>> End')
    
    num +=1
    if num > 5:
        break
# Out:
# <class 'list'>
# <class 'bs4.element.ResultSet'>
# >>>>>>>>> Start
#
#
# >>>>>>>>> End
# >>>>>>>>> Start
#
#
#
#
#
#
# الموديل
#
#
# الشاشة
#
#
# البوردة
#
#
# الغطاء الخلفي
#
#
#
#
#
#
# Galaxy Z Fold 3
#
#
# 9,200
#
#
# 6,200
#
#
# 900
#
#
#
#
# Galaxy Z Fold 2
#
#
# 10,200
#
#
# 7,800
#
#
# 1,000
#
#
#
#
# Galaxy Fold
#
#
# 11,300
#
#
# 6,900
#
#
# 900
#
#
#
#
# Galaxy Z Flip 3
#
#
# 6,000
#
#
# 5,700
#
#
# 500
#
#
#
#
# Galaxy Z Flip
#
#
# 9,500
#
#
# 5,800
#
#
# 1,100
#
#
#
#
# Galaxy Note 20
#
#
# 4,500
#
#
# 5,650
#
#
# 700
#
#
#
#
# Galaxy Note 20 Ultra
#
#
# 5,500
#
#
# 6,000
#
#
# 950
#
#
#
#
# Galaxy Note 10
#
#
# 4,300
#
#
# 5,500
#
#
# 700
#
#
#
#
# Galaxy Note 10 plus
#
#
# 5,200
#
#
# 6,100
#
#
# 700
#
#
#
#
# Galaxy Note 10 lite
#
#
# 3,000
#
#
# 3,700
#
#
# 500
#
#
#
#
# Galaxy Note 9 (512G)
#
#
# 4,000
#
#
# 8,300
#
#
# 800
#
#
#
#
# Galaxy Note 9 (128G)
#
#
# 4,000
#
#
# 5,750
#
#
# 800
#
#
#
#
# Galaxy Note 8
#
#
# 3,450
#
#
# 5,000
#
#
# 570
#
#
#
#
# ...

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd



url = 'https://www.samsung.com/eg/support/partsprices/'
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"
          }
s = requests.Session()
s.headers.update(headers)
r = s.get(url)
soup = bs(r.content , "html.parser")
tables_num = len(soup.findAll('div', class_='ex-g-table-cell-text'))
tables = soup.findAll('div', class_='ex-g-table-cell-text')

table= soup.find('div', class_='ex-g-table-cell-text')
table2 = table.fetchNextSiblings('div', class_='ex-g-table-cell-text')
table_lists = []
table_lists.extend(table)
table_lists.extend(table2)


#print(tables[0:5])
print(len(table2))
print(len(table))
# Out:
# 5
# 2

# %%
#print(soup.prettify()) # للتنسيق
print(type(tables_num))
print(type(table))
print(table)
print('##########')

# %%
mobs = {}
num_id = 0
num = 0
for num in range(1): # عدد الجداول فى الصفحة

    for trr in tables: #
        print(trr)
        #print(type(trr))
        print('>>>>>')
            
        num +=1
        if num > 5:
            break
# Out:
# <div class="ex-g-table-cell-text aem-GridColumn aem-GridColumn--default--12">
# <section class="ex-table__wrap">
# <table class="ex-table-cell-text ex-table-cell-text--align-td-left ex-table-cell-text--align-th-left ex-table-cell-text--layout-fixed margin-top--narrow margin-bottom--normal theme-basic">
# <caption class="blind"></caption>
# <thead>
# <tr>
# <th colspan="1" rowspan="1" scope="col">
# <p>الموديل</p>
# </th>
# <th colspan="1" rowspan="1" scope="col">
# <p>الشاشة</p>
# </th>
# <th colspan="1" rowspan="1" scope="col">
# <p>البوردة</p>
# </th>
# <th colspan="1" rowspan="1" scope="col">
# <p>الغطاء الخلفي</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Galaxy Z Fold 3</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>9,200 </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>6,200</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>900</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Galaxy Z Fold 2</p>
# </td>
# ...

# %% [markdown]
# استيراد المكاتب واستدعائها فى البداية

# %%
print(type(table))
tr_len = table.find_all('tr')
print(len(tr_len))
for mob in range(len(tr_len)):
    name = table.find('p')
    print(name)
# Out:
#   File "C:\Users\Mo\AppData\Local\Temp/ipykernel_10248/3763196603.py", line 5
#     name = table.find('p')[]
#                            ^
# SyntaxError: invalid syntax

# %%
num = 0
tr_len = len(table.find_all('p'))

print(tr_len)
for dev in range(tr_len):
    dev = table.find_all('p')
    p = dev.find('p')
    print(p)
# Out:
# 60
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11452/1423215463.py in <module>
#       5 for dev in range(tr_len):
#       6     dev = table.find_all('p')
# ----> 7     p = dev.find('p')
#       8     print(p)
#
# g:\Projects\Proj Mobi Store\venv\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2252         """Raise a helpful exception to explain a common code fix."""
#    2253         raise AttributeError(
# -> 2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
print(soup.table.tr.findAll('p'))
#print(soup.contents)
# Out:
# [<p>الموديل</p>, <p>الشاشة</p>, <p>البوردة</p>, <p>الغطاء الخلفي</p>]
